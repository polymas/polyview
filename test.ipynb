# %%
import requests

res = requests.get("http://localhost:8000/activity?user=0x45deaaD70997b2998FBb9433B1819178e34B409C&limit=-1")

# %%
res.json()
from collections import defaultdict

data = res.json().get('data', [])
grouped = defaultdict(list)
for item in data:
    cid = item.get('conditionId')
    grouped[cid].append(item)
# 现在 grouped 是以 conditionId 为键分组的字典

# %%
list(grouped.keys())[-2]
# Out:
# '0xda44a00e531df25d06dd4803eea5ef3f560d6547a8a2ddae999c6ac315b526d2'

# %%
grouped[list(grouped.keys())[-2]]
# Out:
# [{'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1764631764,
#   'conditionId': '0xda44a00e531df25d06dd4803eea5ef3f560d6547a8a2ddae999c6ac315b526d2',
#   'type': 'TRADE',
#   'size': 200,
#   'usdcSize': 199.8,
#   'transactionHash': '0x8368862c951de64dfa888c46fed699e87557106f48714cd8bf91084da01c46a3',
#   'price': 0.999,
#   'asset': '103416784312996676048434496086641484448905697419107233713255741821753197651625',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Will Watford FC win on 2025-12-01?',
#   'slug': 'elc-bir-wat-2025-12-01-wat',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/efl-championship-logo.png',
#   'eventSlug': 'elc-bir-wat-2025-12-01',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''}]

# %%
from py_clob_client.client import ClobClient
from py_clob_client.clob_types import OrderArgs, OrderType
from py_clob_client.order_builder.constants import BUY

host: str = "https://clob.polymarket.com"
key: str = "0x7b99abf71ae90612a563d39224d8043ae95d52838af03233b033a3ba515be063" #This is your Private Key. Export from https://reveal.magic.link/polymarket or from your Web3 Extension
chain_id: int = 137 #No need to adjust this
client = ClobClient(host, key=key, chain_id=chain_id, signature_type=1, funder="123")
client.create_or_derive_api_creds()

res = client.create_or_derive_api_creds()
print(res.api_key)
print(res.api_secret)
print(res.api_passphrase)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# SSLError: [SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
# ...
