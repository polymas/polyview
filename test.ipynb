# %%
"""
Polymarket Data-API 完整实现
基于官方文档: https://docs.polymarket.com/api-reference/data-api
"""

import requests
import json
from typing import Optional, List, Dict, Any
from datetime import datetime

# Data-API 基础 URL
BASE_URL = "https://data-api.polymarket.com"

class PolymarketDataAPI:
    """Polymarket Data-API 客户端"""
    
    def __init__(self, base_url: str = BASE_URL):
        self.base_url = base_url
        self.session = requests.Session()
        self.session.headers.update({
            'Accept': 'application/json',
            'Content-Type': 'application/json'
        })
    
    def _get(self, endpoint: str, params: Optional[Dict] = None) -> Dict[str, Any]:
        """发送 GET 请求"""
        url = f"{self.base_url}{endpoint}"
        try:
            response = self.session.get(url, params=params, timeout=30)
            response.raise_for_status()
            return response.json()
        except requests.exceptions.RequestException as e:
            print(f"请求失败: {e}")
            if hasattr(e.response, 'text'):
                print(f"响应内容: {e.response.text}")
            raise
    
    # ==================== Health ====================
    
    def health_check(self) -> Dict[str, Any]:
        """
        健康检查端点
        GET /health
        """
        return self._get("/health")
    
    # ==================== Core Endpoints ====================
    
    def get_positions(
        self,
        user: str,
        market: Optional[List[str]] = None,
        event_id: Optional[List[int]] = None,
        size_threshold: float = 1.0,
        redeemable: bool = False,
        mergeable: bool = False,
        limit: int = 100,
        offset: int = 0,
        sort_by: str = "TOKENS",
        sort_direction: str = "DESC",
        title: Optional[str] = None
    ) -> List[Dict[str, Any]]:
        """
        获取用户当前持仓
        GET /positions
        
        参数:
            user: 用户地址 (0x开头的40位十六进制字符串，必需)
            market: 条件ID列表 (逗号分隔，与event_id互斥)
            event_id: 事件ID列表 (逗号分隔，与market互斥)
            size_threshold: 持仓大小阈值 (默认: 1.0)
            redeemable: 是否可赎回 (默认: False)
            mergeable: 是否可合并 (默认: False)
            limit: 返回数量限制 (默认: 100, 范围: 0-500)
            offset: 偏移量 (默认: 0, 范围: 0-10000)
            sort_by: 排序字段 (CURRENT, INITIAL, TOKENS, CASHPNL, PERCENTPNL, TITLE, RESOLVING, PRICE, AVGPRICE)
            sort_direction: 排序方向 (ASC, DESC)
            title: 标题搜索 (最大长度: 100)
        """
        params = {
            "user": user,
            "sizeThreshold": size_threshold,
            "redeemable": redeemable,
            "mergeable": mergeable,
            "limit": limit,
            "offset": offset,
            "sortBy": sort_by,
            "sortDirection": sort_direction
        }
        
        if market:
            params["market"] = ",".join(market)
        if event_id:
            params["eventId"] = ",".join(map(str, event_id))
        if title:
            params["title"] = title
        
        return self._get("/positions", params=params)
    
    def get_trades(
        self,
        user: Optional[str] = None,
        market: Optional[List[str]] = None,
        event_id: Optional[List[int]] = None,
        limit: int = 100,
        offset: int = 0,
        sort_by: str = "TIMESTAMP",
        sort_direction: str = "DESC"
    ) -> List[Dict[str, Any]]:
        """
        获取用户或市场的交易记录
        GET /trades
        
        参数:
            user: 用户地址 (可选)
            market: 条件ID列表 (可选)
            event_id: 事件ID列表 (可选)
            limit: 返回数量限制 (默认: 100)
            offset: 偏移量 (默认: 0)
            sort_by: 排序字段 (默认: TIMESTAMP)
            sort_direction: 排序方向 (ASC, DESC)
        """
        params = {
            "limit": limit,
            "offset": offset,
            "sortBy": sort_by,
            "sortDirection": sort_direction
        }
        
        if user:
            params["user"] = user
        if market:
            params["market"] = ",".join(market)
        if event_id:
            params["eventId"] = ",".join(map(str, event_id))
        
        return self._get("/trades", params=params)
    
    def get_user_activity(
        self,
        user: str,
        limit: int = 100,
        offset: int = 0,
        sort_by: str = "TIMESTAMP",
        sort_direction: str = "DESC"
    ) -> List[Dict[str, Any]]:
        """
        获取用户活动
        GET /activity
        
        参数:
            user: 用户地址 (必需)
            limit: 返回数量限制 (默认: 100)
            offset: 偏移量 (默认: 0)
            sort_by: 排序字段 (默认: TIMESTAMP)
            sort_direction: 排序方向 (ASC, DESC)
        """
        params = {
            "user": user,
            "limit": limit,
            "offset": offset,
            "sortBy": sort_by,
            "sortDirection": sort_direction
        }
        
        return self._get("/activity", params=params)
    
    def get_all_user_activity(
        self,
        user: str,
        sort_by: str = "TIMESTAMP",
        sort_direction: str = "DESC",
        batch_size: int = 100,
        max_records: Optional[int] = None,
        verbose: bool = True
    ) -> List[Dict[str, Any]]:
        """
        循环获取用户的所有历史活动记录
        
        参数:
            user: 用户地址 (必需)
            sort_by: 排序字段 (默认: TIMESTAMP)
            sort_direction: 排序方向 (ASC, DESC)
            batch_size: 每批获取的记录数 (默认: 100, 最大: 500)
            max_records: 最大获取记录数 (None 表示获取所有记录)
            verbose: 是否显示进度信息 (默认: True)
        
        返回:
            所有活动记录的列表
        """
        all_activities = []
        offset = 0
        batch_size = min(batch_size, 500)  # API 限制最大 500
        
        if verbose:
            print(f"开始获取用户 {user} 的所有活动记录...")
        
        while True:
            try:
                if verbose:
                    print(f"正在获取第 {offset // batch_size + 1} 批 (offset: {offset}, limit: {batch_size})...")
                
                # 获取当前批次
                batch = self.get_user_activity(
                    user=user,
                    limit=batch_size,
                    offset=offset,
                    sort_by=sort_by,
                    sort_direction=sort_direction
                )
                
                # 如果没有数据，说明已经获取完所有记录
                if not batch or len(batch) == 0:
                    if verbose:
                        print("已获取所有记录")
                    break
                
                # 添加到总列表
                all_activities.extend(batch)
                
                if verbose:
                    print(f"  已获取 {len(batch)} 条记录，累计: {len(all_activities)} 条")
                
                # 如果返回的记录数少于 batch_size，说明已经是最后一批
                if len(batch) < batch_size:
                    if verbose:
                        print("已获取所有记录（最后一批）")
                    break
                
                # 如果设置了最大记录数限制
                if max_records and len(all_activities) >= max_records:
                    all_activities = all_activities[:max_records]
                    if verbose:
                        print(f"已达到最大记录数限制: {max_records}")
                    break
                
                # 更新偏移量，准备获取下一批
                offset += batch_size
                
                # 安全限制：防止无限循环（API 限制 offset 最大 10000）
                if offset > 10000:
                    if verbose:
                        print(f"警告: 已达到 API 偏移量限制 (10000)，停止获取")
                    break
                
            except Exception as e:
                print(f"获取数据时出错: {e}")
                break
        
        if verbose:
            print(f"\n总共获取了 {len(all_activities)} 条活动记录")
        
        return all_activities
    
    def get_top_holders(
        self,
        market: Optional[str] = None,
        event_id: Optional[int] = None,
        limit: int = 100,
        offset: int = 0
    ) -> List[Dict[str, Any]]:
        """
        获取市场顶级持有者
        GET /top-holders
        
        参数:
            market: 条件ID (与event_id互斥)
            event_id: 事件ID (与market互斥)
            limit: 返回数量限制 (默认: 100)
            offset: 偏移量 (默认: 0)
        """
        params = {
            "limit": limit,
            "offset": offset
        }
        
        if market:
            params["market"] = market
        if event_id:
            params["eventId"] = event_id
        
        return self._get("/top-holders", params=params)
    
    def get_total_value(
        self,
        user: str,
        market: Optional[List[str]] = None,
        event_id: Optional[List[int]] = None
    ) -> Dict[str, Any]:
        """
        获取用户持仓总价值
        GET /total-value
        
        参数:
            user: 用户地址 (必需)
            market: 条件ID列表 (可选)
            event_id: 事件ID列表 (可选)
        """
        params = {"user": user}
        
        if market:
            params["market"] = ",".join(market)
        if event_id:
            params["eventId"] = ",".join(map(str, event_id))
        
        return self._get("/total-value", params=params)
    
    def get_closed_positions(
        self,
        user: str,
        market: Optional[List[str]] = None,
        event_id: Optional[List[int]] = None,
        limit: int = 100,
        offset: int = 0,
        sort_by: str = "TIMESTAMP",
        sort_direction: str = "DESC"
    ) -> List[Dict[str, Any]]:
        """
        获取用户已关闭的持仓
        GET /closed-positions
        
        参数:
            user: 用户地址 (必需)
            market: 条件ID列表 (可选)
            event_id: 事件ID列表 (可选)
            limit: 返回数量限制 (默认: 100)
            offset: 偏移量 (默认: 0)
            sort_by: 排序字段 (默认: TIMESTAMP)
            sort_direction: 排序方向 (ASC, DESC)
        """
        params = {
            "user": user,
            "limit": limit,
            "offset": offset,
            "sortBy": sort_by,
            "sortDirection": sort_direction
        }
        
        if market:
            params["market"] = ",".join(market)
        if event_id:
            params["eventId"] = ",".join(map(str, event_id))
        
        return self._get("/closed-positions", params=params)
    
    def get_trader_leaderboard(
        self,
        period: str = "ALL_TIME",
        limit: int = 100,
        offset: int = 0
    ) -> List[Dict[str, Any]]:
        """
        获取交易员排行榜
        GET /trader-leaderboard
        
        参数:
            period: 时间周期 (ALL_TIME, WEEK, MONTH, YEAR)
            limit: 返回数量限制 (默认: 100)
            offset: 偏移量 (默认: 0)
        """
        params = {
            "period": period,
            "limit": limit,
            "offset": offset
        }
        
        return self._get("/trader-leaderboard", params=params)


# ==================== 使用示例 ====================

# 创建 API 客户端实例
api = PolymarketDataAPI()

print("Polymarket Data-API 客户端已创建")
print(f"基础 URL: {api.base_url}")
print("\n可用方法:")
print("- health_check() - 健康检查")
print("- get_positions(user, ...) - 获取用户当前持仓")
print("- get_trades(user=None, market=None, ...) - 获取交易记录")
print("- get_user_activity(user, ...) - 获取用户活动")
print("- get_all_user_activity(user, ...) - 循环获取所有历史活动记录")
print("- get_top_holders(market=None, event_id=None, ...) - 获取顶级持有者")
print("- get_total_value(user, ...) - 获取持仓总价值")
print("- get_closed_positions(user, ...) - 获取已关闭持仓")
print("- get_trader_leaderboard(period='ALL_TIME', ...) - 获取交易员排行榜")
# Out:
# Polymarket Data-API 客户端已创建
# 基础 URL: https://data-api.polymarket.com
#
# 可用方法:
# - health_check() - 健康检查
# - get_positions(user, ...) - 获取用户当前持仓
# - get_trades(user=None, market=None, ...) - 获取交易记录
# - get_user_activity(user, ...) - 获取用户活动
# - get_all_user_activity(user, ...) - 循环获取所有历史活动记录
# - get_top_holders(market=None, event_id=None, ...) - 获取顶级持有者
# - get_total_value(user, ...) - 获取持仓总价值
# - get_closed_positions(user, ...) - 获取已关闭持仓
# - get_trader_leaderboard(period='ALL_TIME', ...) - 获取交易员排行榜

# %%
import requests
BASE_URL = "https://data-api.polymarket.com"
def get_user_activity(
        user: str,
        limit: int = 100,
        offset: int = 0,
        sort_by: str = "TIMESTAMP",
        sort_direction: str = "DESC"
    ) -> List[Dict[str, Any]]:
        """
        获取用户活动
        GET /activity
        
        参数:
            user: 用户地址 (必需)
            limit: 返回数量限制 (默认: 100)
            offset: 偏移量 (默认: 0)
            sort_by: 排序字段 (默认: TIMESTAMP)
            sort_direction: 排序方向 (ASC, DESC)
        """
        params = {
            "user": user,
            "limit": limit,
            "offset": offset,
            "sortBy": sort_by,
            "sortDirection": sort_direction
        }
        
        return requests.get(BASE_URL+"/activity", params=params)
res = get_user_activity("0x45deaaD70997b2998FBb9433B1819178e34B409C")

# %%
res.json()
# Out:
# [{'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766471661,
#   'conditionId': '0x880d5c2aab3fd10c0e18efbf62e0fa724472473e244e08b11d9b73b89d21b52c',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x99cfeb680bc13ae0d1093cbf882f1d4337a908b588edde82f98a95700102ab0d',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Will Drake release a new song in 2025?',
#   'slug': 'will-drake-release-a-new-song-in-2025',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/which-artists-will-release-new-albums-in-2025-AfUvGA90JtU_.jpg',
#   'eventSlug': 'which-artists-will-release-a-new-song-before-2026',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766470943,
#   'conditionId': '0xe5e828881862659c7c8922c0ea7d800178347e1d267739a4cf1632bb5fc5e74d',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x1121b6501b02d9d3105733173f58c867a63572575e4c5b1518d510ff46d0c9ca',
#   'price': 0.999,
#   'asset': '33649978589665424442504118092567057226258603678103290087215943776899735490551',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Ryan Kalkbrenner: Points Over 7.5',
#   'slug': 'nba-cha-cle-2025-12-22-points-ryan-kalkbrenner-7pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventSlug': 'nba-cha-cle-2025-12-22',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766470559,
#   'conditionId': '0xc966b010228f6b18984d956a5dad8801e21a0db48c4136061ad8be6e7c7e750d',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x5651952acc6a0b5042736b6c89b97d554f47719bf29e1ac79ab0bf37457c9b65',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': '49ers Team Total: O/U 35.5',
#   'slug': 'nfl-sf-ind-2025-12-22-team-total-sf-35pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventSlug': 'nfl-sf-ind-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766469275,
#   'conditionId': '0x8d3e2dc65ba3094c93bf381735a45d8d75bc2682931c18280bc90e44716f9c78',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x57d2b0fe96a40f6d2ae59261f5d4e6a1ef372c8e3bc19fb3a52e4f724278e7a0',
#   'price': 0.999,
#   'asset': '15031933451723829282802163966839710216261680674848844554397524284162498410305',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Donovan Mitchell: Points Over 30.5',
#   'slug': 'nba-cha-cle-2025-12-22-points-donovan-mitchell-30pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventSlug': 'nba-cha-cle-2025-12-22',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766469263,
#   'conditionId': '0x1f9912d1ddce99146c80bb5e21b6bb839706580293f58f58d15d3ae3f6b2e62b',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0xedabccd709e1208446ac5418591ff2b93da081c03e4414a597297cf2b95715f0',
#   'price': 0.999,
#   'asset': '33114567199551258112990526666438295666229059628960593875544939087297589059888',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Jaylon Tyson: Points Over 13.5',
#   'slug': 'nba-cha-cle-2025-12-22-points-jaylon-tyson-13pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventSlug': 'nba-cha-cle-2025-12-22',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766469247,
#   'conditionId': '0xc88733b186cc96e1988aaab4cc181bcbb8a48b15f9941f8b430901c44a334074',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x8bd84a4f06fa5a85850da25878c95a6fc6233c3f897531eeabddae7685cb95ec',
#   'price': 0.999,
#   'asset': '68430888952566460415180690900907046862987451203435580894217508967813596061393',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'Brandon Miller: Points Over 19.5',
#   'slug': 'nba-cha-cle-2025-12-22-points-brandon-miller-19pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventSlug': 'nba-cha-cle-2025-12-22',
#   'outcome': 'Yes',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766469247,
#   'conditionId': '0x393d7f1433ac82ef914af1f2974ee84082d65af6e39dd1932d53cf97a0649b29',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0xe1dfc9e2d411c3fa5962ce8561151661e86e531d5cef828adb5f224a8b2c28c1',
#   'price': 0.999,
#   'asset': '107798311420325803277519642282592105212181714727224597221712051226608726440775',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Jarrett Allen: Points Over 14.5',
#   'slug': 'nba-cha-cle-2025-12-22-points-jarrett-allen-14pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventSlug': 'nba-cha-cle-2025-12-22',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766469227,
#   'conditionId': '0x55af401a664f17463a476458e5f829125850b477ffedc6dd11706dd61d3f082f',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x6d7cea8f0bdbeb6c65d929b2fc59442de89c6d064ca664e8238343a9da5b1ee1',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Grizzlies vs. Thunder: 1H O/U 118.5',
#   'slug': 'nba-mem-okc-2025-12-22-1h-total-118pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventSlug': 'nba-mem-okc-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766469191,
#   'conditionId': '0x7f9dca8e9b91747ab1358d5d14abd9c57e4c451cd26c0ae2549720a6ea5dde66',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x15c13fabc8876ae0a971efa5736caae46fae0693d193f08d8b6f4e1ec1959068',
#   'price': 0.999,
#   'asset': '75582063466488539264962380394994221487486687070949116383576167248773419859537',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Miles Bridges: Points Over 18.5',
#   'slug': 'nba-cha-cle-2025-12-22-points-miles-bridges-18pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventSlug': 'nba-cha-cle-2025-12-22',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766467777,
#   'conditionId': '0x0be0c550c8757bb788d09cb9a39d06a5145f35e3bac14136e580e01d29bd918a',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0xf881c12da281ec061cceddff547d3b32596e21258c14b05877bd62d505d0eb35',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Spread: Flyers (-1.5)',
#   'slug': 'nhl-van-phi-2025-12-22-spread-home-1pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'eventSlug': 'nhl-van-phi-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766467409,
#   'conditionId': '0x7672be3afa22c068b9e02f72b6c37e9db06b7fc3535f9e3da520a197e48c3486',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x1b059971f703ee920684c66c482ace3d4e3ab7c6d8e5d9f29051063161305236',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Will the highest temperature in London be 8°C on December 23?',
#   'slug': 'highest-temperature-in-london-on-december-23-8c',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/highest-temperature-in-london-on-jan-22-eouu0bkjph8i.jpg',
#   'eventSlug': 'highest-temperature-in-london-on-december-23',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766467393,
#   'conditionId': '0xa125f438059a4901813509680315a600d7828fcc43d321af2dfbb6c26e1d30be',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x7a8405f38e57df6bf1b1a0b10c79bfa3c585f696da1c612449d68ba21d2badd5',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': '49ers Team Total: O/U 24.5',
#   'slug': 'nfl-sf-ind-2025-12-22-team-total-sf-24pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventSlug': 'nfl-sf-ind-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766467343,
#   'conditionId': '0x7ca96f44206fa32c56737c12b8e70b14eee0d04fcac8fb807b39c0eed961c70f',
#   'type': 'TRADE',
#   'size': 10,
#   'usdcSize': 9.99,
#   'transactionHash': '0xd57f6fe9ea009928ad85754c99eb896a8dccfb21fe76060a79d4d87e608e1166',
#   'price': 0.999,
#   'asset': '70425382902868671237532198340653528400437842617608663489917057266394662427292',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'Will the San Francisco 49ers win 11 or more regular season games?',
#   'slug': 'will-the-san-francisco-49ers-win-11-or-more-regular-season-games',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/NFL+Team+Logos/SF.png',
#   'eventSlug': 'nfl-win-totals-over-or-under',
#   'outcome': 'Yes',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766467329,
#   'conditionId': '0xe09411bc2b04c603d37d7f147460a78747dde62e0bf98b828f46053100afe0e2',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x8c4abe3018aed25465ed6e7e6eed33e6071fe2d5297de2f8eddf918e904154c8',
#   'price': 0.999,
#   'asset': '104941113245161932232820871569023846778537491670117468506919192708056817865421',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Grizzlies vs. Thunder: O/U 227.5',
#   'slug': 'nba-mem-okc-2025-12-22-total-227pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventSlug': 'nba-mem-okc-2025-12-22',
#   'outcome': 'Under',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766467265,
#   'conditionId': '0x36c4292e0ccc02253b798c3f2860f2c677631d5afcde73b2786c434f3cefeb0d',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0xde21b124db5eb7c3b5f235a23f74f392d5c457f6adc99d6f2ce42aeeaa5e35aa',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Illinois Fighting Illini vs. Missouri Tigers',
#   'slug': 'cbb-ill-missr-2025-12-22',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ncaa-c14995df96.png',
#   'eventSlug': 'cbb-ill-missr-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766466895,
#   'conditionId': '0x09c3e4125149cab13f657abc3e7196aaea017b8df6a339e88570e434a5813d94',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0xe6c8db6885a0b19892319971c66d63b074a168bb91d74bc404d891951a9077c9',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Will the highest temperature in Seoul be 5°C on December 23?',
#   'slug': 'highest-temperature-in-seoul-on-december-23-5c',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/highest-temperature-in-seoul-on-december-6-WzqtMeHg43n4.jpg',
#   'eventSlug': 'highest-temperature-in-seoul-on-december-23',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766466409,
#   'conditionId': '0xc966b010228f6b18984d956a5dad8801e21a0db48c4136061ad8be6e7c7e750d',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x7732a3713043fcf2aece0f0f93c17f766c1f1c08e394f88284b0924e8640fea0',
#   'price': 0.999,
#   'asset': '2479953984663019710584490212308767123997218037709782686695294465256827752073',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': '49ers Team Total: O/U 35.5',
#   'slug': 'nfl-sf-ind-2025-12-22-team-total-sf-35pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventSlug': 'nfl-sf-ind-2025-12-22',
#   'outcome': 'Over',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766465783,
#   'conditionId': '0x0d8ba522af1836ea22bbe8fa702d5d535e8a7572a6d72e00117476e3a83e69ba',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x346e5290def81b8c4926a7ed76467d5da29b8a5e2107e561fb353845af0fbc06',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Davidson Wildcats vs. Kansas Jayhawks',
#   'slug': 'cbb-david-kan-2025-12-22',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ncaa-c14995df96.png',
#   'eventSlug': 'cbb-david-kan-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766464187,
#   'conditionId': '0x55af401a664f17463a476458e5f829125850b477ffedc6dd11706dd61d3f082f',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0xaf203397400aaeb0cfa2bf0d32f005e0d5597277135a46af4c8d9443c9716fc4',
#   'price': 0.999,
#   'asset': '11589969498023891177257600651140557373670350684815882643706053419154959323234',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'Grizzlies vs. Thunder: 1H O/U 118.5',
#   'slug': 'nba-mem-okc-2025-12-22-1h-total-118pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventSlug': 'nba-mem-okc-2025-12-22',
#   'outcome': 'Over',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766464083,
#   'conditionId': '0xd005e704f8598ab39d770668f4d78ea37c1aac01b0d2dd0b1b1f6c10c7f6463b',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0xa1afa79ee82f18987ed52846491893d98738ecc1b5b4159fa4ce527a685e1848',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Colts Team Total: O/U 13.5',
#   'slug': 'nfl-sf-ind-2025-12-22-team-total-ind-13pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventSlug': 'nfl-sf-ind-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766462107,
#   'conditionId': '0x36c4292e0ccc02253b798c3f2860f2c677631d5afcde73b2786c434f3cefeb0d',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x98b77dabda57687d6dceb81984bdda91c8cfc885a28a5f3c218829d706bc5d39',
#   'price': 0.999,
#   'asset': '106808752061654312849524696245000439665314646978813353215422138058009723142074',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'Illinois Fighting Illini vs. Missouri Tigers',
#   'slug': 'cbb-ill-missr-2025-12-22',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ncaa-c14995df96.png',
#   'eventSlug': 'cbb-ill-missr-2025-12-22',
#   'outcome': 'Illinois Fighting Illini',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766461061,
#   'conditionId': '0x0d8ba522af1836ea22bbe8fa702d5d535e8a7572a6d72e00117476e3a83e69ba',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0xc26e3c2b8119ed458da2a6906139aa908a1a8ed1d9bb25da28c7111fa6ab0604',
#   'price': 0.999,
#   'asset': '54329132944065205128769436512282891903641832508882579425260649803824011023958',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Davidson Wildcats vs. Kansas Jayhawks',
#   'slug': 'cbb-david-kan-2025-12-22',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ncaa-c14995df96.png',
#   'eventSlug': 'cbb-david-kan-2025-12-22',
#   'outcome': 'Kansas Jayhawks',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766460997,
#   'conditionId': '0x0be0c550c8757bb788d09cb9a39d06a5145f35e3bac14136e580e01d29bd918a',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x7e9d954a31ca71e1e818ac62ab17b2ff84b30b9e809e428372bb01e1b0c9b268',
#   'price': 0.999,
#   'asset': '22430872565751616242682704024366809068182072391539057495474087615940530046587',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'Spread: Flyers (-1.5)',
#   'slug': 'nhl-van-phi-2025-12-22-spread-home-1pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nhl.png',
#   'eventSlug': 'nhl-van-phi-2025-12-22',
#   'outcome': 'Flyers',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766460949,
#   'conditionId': '0xa125f438059a4901813509680315a600d7828fcc43d321af2dfbb6c26e1d30be',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x765daec41c4ec1622f2fd49a18aca54d676eb5cb3e32922dea6213093f603d6a',
#   'price': 0.999,
#   'asset': '1182219880348986474698508812756676550553377195186284895341957726103851591226',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': '49ers Team Total: O/U 24.5',
#   'slug': 'nfl-sf-ind-2025-12-22-team-total-sf-24pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventSlug': 'nfl-sf-ind-2025-12-22',
#   'outcome': 'Over',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766460329,
#   'conditionId': '0xd7e0ce2dba4e9362c6b860f10cda8dd4ffc1e4fad8f2d1506627ce0eab3f3f27',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x74f5999d8b15fade5f2b716679bcbb0211b4b28c308443a95a34794e48b6eb0c',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Hornets vs. Cavaliers: 1H Moneyline',
#   'slug': 'nba-cha-cle-2025-12-22-1h-moneyline',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventSlug': 'nba-cha-cle-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766460329,
#   'conditionId': '0x429ff0d8cc9cdc3bfbc8b242b5f60629ceaf4188093301e17fb9695705306e78',
#   'type': 'REDEEM',
#   'size': 59,
#   'usdcSize': 59,
#   'transactionHash': '0x74f5999d8b15fade5f2b716679bcbb0211b4b28c308443a95a34794e48b6eb0c',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': '1H Spread: Cavaliers (-5.5)',
#   'slug': 'nba-cha-cle-2025-12-22-1h-spread-home-5pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventSlug': 'nba-cha-cle-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766460329,
#   'conditionId': '0xaf27504221b7e3b946142f8666edb2f442736d2e5e0c7ac757b0a106f2c8b55f',
#   'type': 'REDEEM',
#   'size': 0.095642,
#   'usdcSize': 0.095642,
#   'transactionHash': '0x74f5999d8b15fade5f2b716679bcbb0211b4b28c308443a95a34794e48b6eb0c',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Will the price of Ethereum be above $3,100 on December 17?',
#   'slug': 'ethereum-above-3100-on-december-17',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ETH+fullsize.jpg',
#   'eventSlug': 'ethereum-above-on-december-17',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766459699,
#   'conditionId': '0x010cad1eef06832ed7406af763761f1437d665344918748284e96cfc2c667d62',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0xa8339627534be2d405cfd86236eff2657df002a62dfed9ad8ea60c655de126d3',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'American Eagles vs. Virginia Cavaliers',
#   'slug': 'cbb-amercn-vir-2025-12-22',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ncaa-c14995df96.png',
#   'eventSlug': 'cbb-amercn-vir-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766458597,
#   'conditionId': '0xf311f156cd776e2cb519d35f8064d43ff07fdf4869ba241a82f3ba314a72555a',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0xc169d488fdd4df70dcd2efc0eec87b041854624d5f8d84f3e8fc4d6aee6f46dd',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'American Eagles vs. Virginia Cavaliers: O/U 153.5',
#   'slug': 'cbb-amercn-vir-2025-12-22-total-153pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ncaa-c14995df96.png',
#   'eventSlug': 'cbb-amercn-vir-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766457759,
#   'conditionId': '0x429ff0d8cc9cdc3bfbc8b242b5f60629ceaf4188093301e17fb9695705306e78',
#   'type': 'TRADE',
#   'size': 59,
#   'usdcSize': 58.941,
#   'transactionHash': '0x124557773b48f2f8f56e497e787b0a132c6a117afe2bf229f7475fd7ee3458b1',
#   'price': 0.999,
#   'asset': '52025669253864673015141573600742928508497536499862982659602760969261405795437',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': '1H Spread: Cavaliers (-5.5)',
#   'slug': 'nba-cha-cle-2025-12-22-1h-spread-home-5pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventSlug': 'nba-cha-cle-2025-12-22',
#   'outcome': 'Cavaliers',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766457333,
#   'conditionId': '0xd005e704f8598ab39d770668f4d78ea37c1aac01b0d2dd0b1b1f6c10c7f6463b',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x23ebb987c528410797710bab5ecd29d02cd7c19db09175feea8968b75ebc0c1d',
#   'price': 0.999,
#   'asset': '23157194193872310116934502808070830429016352449261857857886495012947048114725',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'Colts Team Total: O/U 13.5',
#   'slug': 'nfl-sf-ind-2025-12-22-team-total-ind-13pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/nfl.png',
#   'eventSlug': 'nfl-sf-ind-2025-12-22',
#   'outcome': 'Over',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766457317,
#   'conditionId': '0x880d5c2aab3fd10c0e18efbf62e0fa724472473e244e08b11d9b73b89d21b52c',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.88705,
#   'transactionHash': '0xfbe5f5509262b9ed23862730ca1dd11dad6c89c6431874ff443a0d1085a2337f',
#   'price': 0.9988705,
#   'asset': '7621276605943982448597744222348001591003523523087864349903649924505475669007',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'Will Drake release a new song in 2025?',
#   'slug': 'will-drake-release-a-new-song-in-2025',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/which-artists-will-release-new-albums-in-2025-AfUvGA90JtU_.jpg',
#   'eventSlug': 'which-artists-will-release-a-new-song-before-2026',
#   'outcome': 'Yes',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766457131,
#   'conditionId': '0xd7e0ce2dba4e9362c6b860f10cda8dd4ffc1e4fad8f2d1506627ce0eab3f3f27',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0xbeb35bbbdf6dddeb602820e6b84555081b0b93e84bd966f6b053cbc4e11a4945',
#   'price': 0.999,
#   'asset': '22696197822128705851484933292913162123298621119768523850835353425017327150456',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Hornets vs. Cavaliers: 1H Moneyline',
#   'slug': 'nba-cha-cle-2025-12-22-1h-moneyline',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/super+cool+basketball+in+red+and+blue+wow.png',
#   'eventSlug': 'nba-cha-cle-2025-12-22',
#   'outcome': 'Cavaliers',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766456425,
#   'conditionId': '0x09c3e4125149cab13f657abc3e7196aaea017b8df6a339e88570e434a5813d94',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x0027fea2bb3e43322ee448df42ed2b8848344c0e4fa673a35512a5934b7a6b15',
#   'price': 0.999,
#   'asset': '88204058856810835710062056684869114990722131585123888698376670174981995310781',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Will the highest temperature in Seoul be 5°C on December 23?',
#   'slug': 'highest-temperature-in-seoul-on-december-23-5c',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/highest-temperature-in-seoul-on-december-6-WzqtMeHg43n4.jpg',
#   'eventSlug': 'highest-temperature-in-seoul-on-december-23',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766456053,
#   'conditionId': '0xba5bf76db0054cb8cfc3b0135f9cc26ec438c282bfb5900bd0d44d2c18c2fb19',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x9da3afd5c316644b72daf17ef7cd4b166af666b4fd76e1f73e4c8961cad9efaf',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Abilene Christian Wildcats vs. Texas Southern Tigers',
#   'slug': 'cbb-abchr-txs-2025-12-22',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ncaa-c14995df96.png',
#   'eventSlug': 'cbb-abchr-txs-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766455815,
#   'conditionId': '0x7672be3afa22c068b9e02f72b6c37e9db06b7fc3535f9e3da520a197e48c3486',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0xc958e3b48abdfd88076cffd94d90dafb807e8e38f70ded22c4db4edb27b7fdb7',
#   'price': 0.999,
#   'asset': '42235127358266299720892850503932178096205561262185213296664879366868271546107',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Will the highest temperature in London be 8°C on December 23?',
#   'slug': 'highest-temperature-in-london-on-december-23-8c',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/highest-temperature-in-london-on-jan-22-eouu0bkjph8i.jpg',
#   'eventSlug': 'highest-temperature-in-london-on-december-23',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766455683,
#   'conditionId': '0x378188c1a92300b5690c8fd07b4546fc7598d87990d5b8f80c58eded63a6f47d',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x030707a7d1b9b8a82e7c142f95ad1af6d013350ee4e8d74f51f7a938c7df8de6',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Will Joe Cullen win the PDC World Darts Championship?',
#   'slug': 'will-joe-cullen-win-the-pdc-world-darts-championship',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/arch-pdc-world-darts-championship-winner-T92fSM8FlMf6.png',
#   'eventSlug': 'pdc-world-darts-championship-winner',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766455683,
#   'conditionId': '0x9ece79da62b998470f74f62836265d1c4242584fa0b0f4049279a8427db627f8',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x030707a7d1b9b8a82e7c142f95ad1af6d013350ee4e8d74f51f7a938c7df8de6',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Will "David" Opening Weekend Box Office be between 20m and 24m?',
#   'slug': 'will-david-opening-weekend-box-office-be-between-20m-and-24m',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/david-opening-weekend-box-office-E59xUQNfL3J4.png',
#   'eventSlug': 'david-opening-weekend-box-office',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766455683,
#   'conditionId': '0x7cdc40b4812d3561509d4cb51479bf7137540a019d9e8ece9e4b89fbde7a0860',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x030707a7d1b9b8a82e7c142f95ad1af6d013350ee4e8d74f51f7a938c7df8de6',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Will "David" Opening Weekend Box Office be greater than 32m?',
#   'slug': 'will-david-opening-weekend-box-office-be-greater-than-32m',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/david-opening-weekend-box-office-E59xUQNfL3J4.png',
#   'eventSlug': 'david-opening-weekend-box-office',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766455683,
#   'conditionId': '0xdd8099b2859c89997b4ae7ce57e1d5d97afc650e35285b246f5d9f26b31d3f76',
#   'type': 'REDEEM',
#   'size': 43.59,
#   'usdcSize': 43.59,
#   'transactionHash': '0x030707a7d1b9b8a82e7c142f95ad1af6d013350ee4e8d74f51f7a938c7df8de6',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Will "David" Opening Weekend Box Office be between 24m and 28m?',
#   'slug': 'will-david-opening-weekend-box-office-be-between-24m-and-28m',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/david-opening-weekend-box-office-E59xUQNfL3J4.png',
#   'eventSlug': 'david-opening-weekend-box-office',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766453939,
#   'conditionId': '0x6874c7708bc4b4a079a92b598f98f837f218aebdd14c0b0814bd5d555659d606',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x7b0975ef579b5f11f8ff3a6e321c865eb1694317d706930d45f836f149485956',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Will "Avatar: Fire and Ash" Opening Weekend Box Office be between 90m and 101m?',
#   'slug': 'will-avatar-fire-and-ash-opening-weekend-box-office-be-between-90m-and-101m',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/avatar-fire-and-ash-opening-weekend-box-office-pK2RqUUCw8Xf.png',
#   'eventSlug': 'avatar-fire-and-ash-opening-weekend-box-office',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766452119,
#   'conditionId': '0x010cad1eef06832ed7406af763761f1437d665344918748284e96cfc2c667d62',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x5e8f17f15c5f4b2961a46dc2bc568c0c168aaf6eaeb48a20a2952bae92ce91e4',
#   'price': 0.999,
#   'asset': '81162974573635226280302009096687683303012917346851736517698906429242702696606',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'American Eagles vs. Virginia Cavaliers',
#   'slug': 'cbb-amercn-vir-2025-12-22',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ncaa-c14995df96.png',
#   'eventSlug': 'cbb-amercn-vir-2025-12-22',
#   'outcome': 'Virginia Cavaliers',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766451931,
#   'conditionId': '0xf311f156cd776e2cb519d35f8064d43ff07fdf4869ba241a82f3ba314a72555a',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x90ea7bd5e46debdcfdef5c414ae718bdae527dcb3ec233b27591456edacaecf0',
#   'price': 0.999,
#   'asset': '106504396524969152545276067115742219043787070378252645658158904582536189347811',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'American Eagles vs. Virginia Cavaliers: O/U 153.5',
#   'slug': 'cbb-amercn-vir-2025-12-22-total-153pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ncaa-c14995df96.png',
#   'eventSlug': 'cbb-amercn-vir-2025-12-22',
#   'outcome': 'Under',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766451789,
#   'conditionId': '0x629fe3d2e9033c67afe678e7cea61e204049a5f7212d9f075f1926f2decaa178',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x28ab5dbcfe6ba58311b0d0f6588654c8cfce51f94d0ec84699559f3fbc164b54',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Spread: South Carolina Gamecocks (-31.5)',
#   'slug': 'cbb-scarst-sc-2025-12-22-spread-home-31pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ncaa-c14995df96.png',
#   'eventSlug': 'cbb-scarst-sc-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766451301,
#   'conditionId': '0x79e5434d0f716bf34cdfdeed128923c14032cb165879938adcc04227f3c464bd',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x4d91efda877e8eeb6805472588945e98fc7442f546ecf95f8cf5bbf993fa7798',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Spread: Washington State (-0.5)',
#   'slug': 'cfb-washst-utahst-2025-12-22-spread-away-0pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/espn+college+football+logo.png',
#   'eventSlug': 'cfb-washst-utahst-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766451155,
#   'conditionId': '0x629fe3d2e9033c67afe678e7cea61e204049a5f7212d9f075f1926f2decaa178',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x7c93c43e8fdb1102856223e0258acf0ebcf6ea521521e135da1ec009af9a17d3',
#   'price': 0.999,
#   'asset': '100877475721543553548669790968230391423762274406507003021239189401339263860652',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Spread: South Carolina Gamecocks (-31.5)',
#   'slug': 'cbb-scarst-sc-2025-12-22-spread-home-31pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ncaa-c14995df96.png',
#   'eventSlug': 'cbb-scarst-sc-2025-12-22',
#   'outcome': 'South Carolina State Bulldogs',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766450529,
#   'conditionId': '0xba5bf76db0054cb8cfc3b0135f9cc26ec438c282bfb5900bd0d44d2c18c2fb19',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x0c1039581503a36e81e986664931d2e62fa0aba4c2acc7612dd8efe067ddcd77',
#   'price': 0.999,
#   'asset': '63853162971655426852583319135236782408850864536473009238006746540099891412594',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'Abilene Christian Wildcats vs. Texas Southern Tigers',
#   'slug': 'cbb-abchr-txs-2025-12-22',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ncaa-c14995df96.png',
#   'eventSlug': 'cbb-abchr-txs-2025-12-22',
#   'outcome': 'Abilene Christian Wildcats',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766449489,
#   'conditionId': '0xc4776ab41afc0083cffe7a082ed1ea9bca505d801b40baa47a68208b7c878bb7',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x9774f8898a033930d4b72d38888892c20b18f52b2411d81583aaa461a7553c8c',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Wicked vs Avatar: Bigger Domestic Opening Weekend?',
#   'slug': 'wicked-vs-avatar-bigger-domestic-opening-weekend',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/wicked-for-good-vs-avatar-fire-and-ash-opening-weekend-yBlV-_Pa-oXM.jpg',
#   'eventSlug': 'wicked-vs-avatar-bigger-domestic-opening-weekend',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766448761,
#   'conditionId': '0x7717deecbbe546bb2eca51f3a51e7b93efa05683f36da2c3b8b95db15947610e',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x893fcdcbf37b355b1f7e1966df7b25422a06ebed71967c7f3d2b47120e06a933',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Will the highest temperature in Seattle be between 48-49°F on December 22?',
#   'slug': 'highest-temperature-in-seattle-on-december-22-48-49f',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/highest-temperature-in-seattle-on-december-5-mjogoGN44OY4.jpg',
#   'eventSlug': 'highest-temperature-in-seattle-on-december-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766445165,
#   'conditionId': '0x6874c7708bc4b4a079a92b598f98f837f218aebdd14c0b0814bd5d555659d606',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x5fb101379918091994b44827c2cdd519b20df5de84e25c2a00ff6b41a31f99fd',
#   'price': 0.999,
#   'asset': '7859225243443664355501216908045533725106898224151865079058149391950310662107',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Will "Avatar: Fire and Ash" Opening Weekend Box Office be between 90m and 101m?',
#   'slug': 'will-avatar-fire-and-ash-opening-weekend-box-office-be-between-90m-and-101m',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/avatar-fire-and-ash-opening-weekend-box-office-pK2RqUUCw8Xf.png',
#   'eventSlug': 'avatar-fire-and-ash-opening-weekend-box-office',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766444987,
#   'conditionId': '0x7cdc40b4812d3561509d4cb51479bf7137540a019d9e8ece9e4b89fbde7a0860',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x1cf02bf9dbe116b8968f0b5b6507f3990b2a0151893219d9769ec9303a089dab',
#   'price': 0.999,
#   'asset': '79715987913546812866368855400367882994747526556893058220259389697125584237698',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Will "David" Opening Weekend Box Office be greater than 32m?',
#   'slug': 'will-david-opening-weekend-box-office-be-greater-than-32m',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/david-opening-weekend-box-office-E59xUQNfL3J4.png',
#   'eventSlug': 'david-opening-weekend-box-office',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766444675,
#   'conditionId': '0x79e5434d0f716bf34cdfdeed128923c14032cb165879938adcc04227f3c464bd',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0xb8a6ef34ae90e4159b67410c11e1d80b67df0f715656179afd1efe3e1ef62143',
#   'price': 0.999,
#   'asset': '107073493224277470780725909357563331999890934134234732327728772318528477562034',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'Spread: Washington State (-0.5)',
#   'slug': 'cfb-washst-utahst-2025-12-22-spread-away-0pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/espn+college+football+logo.png',
#   'eventSlug': 'cfb-washst-utahst-2025-12-22',
#   'outcome': 'Washington State',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766444527,
#   'conditionId': '0xdd8099b2859c89997b4ae7ce57e1d5d97afc650e35285b246f5d9f26b31d3f76',
#   'type': 'TRADE',
#   'size': 43.59,
#   'usdcSize': 43.54641,
#   'transactionHash': '0x822c666f2556897ef2fbc913b328306d0e581cd991f82464a91725298f093974',
#   'price': 0.999,
#   'asset': '4190549416985643518289056253303929977843974151769357521566116788032252546413',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Will "David" Opening Weekend Box Office be between 24m and 28m?',
#   'slug': 'will-david-opening-weekend-box-office-be-between-24m-and-28m',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/david-opening-weekend-box-office-E59xUQNfL3J4.png',
#   'eventSlug': 'david-opening-weekend-box-office',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766444507,
#   'conditionId': '0x9ece79da62b998470f74f62836265d1c4242584fa0b0f4049279a8427db627f8',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x1640c759cbb236ad4c71ca5c97279e9761c49a1502ae31bccdb71d8b9da95610',
#   'price': 0.999,
#   'asset': '50378063174946616346762492204002985924252769053069693435478187427557158758295',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'Will "David" Opening Weekend Box Office be between 20m and 24m?',
#   'slug': 'will-david-opening-weekend-box-office-be-between-20m-and-24m',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/david-opening-weekend-box-office-E59xUQNfL3J4.png',
#   'eventSlug': 'david-opening-weekend-box-office',
#   'outcome': 'Yes',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766444421,
#   'conditionId': '0xf83b1faea4b73020eb17ec3fde3cb135c3aeb4de4d78f7894dd43cfcbf17b68d',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x5487f06d7d0f70f6f01ef3055e7dce38ac412c1e34e86892a3a05ab398c94d40',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Spread: Georgia Bulldogs (-36.5)',
#   'slug': 'cbb-uwg-ga-2025-12-22-spread-home-36pt5',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ncaa-c14995df96.png',
#   'eventSlug': 'cbb-uwg-ga-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766442845,
#   'conditionId': '0xc4776ab41afc0083cffe7a082ed1ea9bca505d801b40baa47a68208b7c878bb7',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0xf392e3286adf04ac60a34a1d98efef6a2594e679bb5a13b561dc7212f5e6f4cc',
#   'price': 0.999,
#   'asset': '34153498484182310867481935916725450618359416416133851052215947881985037265739',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'Wicked vs Avatar: Bigger Domestic Opening Weekend?',
#   'slug': 'wicked-vs-avatar-bigger-domestic-opening-weekend',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/wicked-for-good-vs-avatar-fire-and-ash-opening-weekend-yBlV-_Pa-oXM.jpg',
#   'eventSlug': 'wicked-vs-avatar-bigger-domestic-opening-weekend',
#   'outcome': 'Wicked',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766440547,
#   'conditionId': '0x0ac8f2479975ed70dfabf01b8befc580229119eadb442e3851841fd6126bba06',
#   'type': 'REDEEM',
#   'size': 0.11,
#   'usdcSize': 0.11,
#   'transactionHash': '0xa732caee483528a7d2a51e96fc889f40e690ac63ee5f224e737fa79dc0996a8e',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Milligan Buffaloes vs. Miami (OH) RedHawks',
#   'slug': 'cbb-millig-miaoh-2025-12-22',
# ...
#   'timestamp': 1766422187,
#   'conditionId': '0x803da5a1aee8b89145dc42dd69a8212ad861ce88b60c562e83f7d6e557bde0e5',
#   'type': 'TRADE',
#   'size': 5,
#   'usdcSize': 4.995,
#   'transactionHash': '0x1651080f2e51d0ada3a5fecb5f70d02dc4d835517d78d8331b77cee83454798c',
#   'price': 0.999,
#   'asset': '95130164523333975600276747541099267218546238767333062240435197282637276059169',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'Counter-Strike: Team magixx vs Team m3wsu (BO3)',
#   'slug': 'cs2-magixx-mwsu-2025-12-22',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/counter-strike-image-16c415c538.png',
#   'eventSlug': 'cs2-magixx-mwsu-2025-12-22',
#   'outcome': 'Team magixx',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766421513,
#   'conditionId': '0x803da5a1aee8b89145dc42dd69a8212ad861ce88b60c562e83f7d6e557bde0e5',
#   'type': 'TRADE',
#   'size': 0.67,
#   'usdcSize': 0.66933,
#   'transactionHash': '0x1474d980f353a3b131e42a644027640a1d1521e6e9d943a7e9a7ca4d3e265f87',
#   'price': 0.999,
#   'asset': '95130164523333975600276747541099267218546238767333062240435197282637276059169',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'Counter-Strike: Team magixx vs Team m3wsu (BO3)',
#   'slug': 'cs2-magixx-mwsu-2025-12-22',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/counter-strike-image-16c415c538.png',
#   'eventSlug': 'cs2-magixx-mwsu-2025-12-22',
#   'outcome': 'Team magixx',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766420161,
#   'conditionId': '0x8dcdfe9b4bf27c545210332cdafc53e0b66f65593d8001a649e2c86ed6295929',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x4d8a85014696e9c7a24a293315bba0e8ce37bae4e37f6f05e27ef2c9b21335c8',
#   'price': 0.999,
#   'asset': '90306193363227619834672121004604184569390112861253328585364701909899241656522',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'Will "Avatar: Fire and Ash" score at least 65 on the Rotten Tomatoes Tomatometer?',
#   'slug': 'will-avatar-fire-and-ash-score-at-least-65-on-the-rotten-tomatoes-tomatometer',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/zootopia-2-rotten-tomatoes-score.jpg',
#   'eventSlug': 'avatar-fire-and-ash-rotten-tomatoes-score-118',
#   'outcome': 'Yes',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766417535,
#   'conditionId': '0x13e1bdcba66198736d2ef5997c64a1fba24757bdb780b2aa7ef58ed80b11be49',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0xdb79e1874037f8c6fc47a286a9edfec6712bdbb0f7793f1a73ab975b7c7965ef',
#   'price': 0.999,
#   'asset': '65822594241467460163910625032648351360233831037893920014319484276105153620743',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'Will "Avatar: Fire and Ash" score at least 60 on the Rotten Tomatoes Tomatometer?',
#   'slug': 'will-avatar-fire-and-ash-score-at-least-60-on-the-rotten-tomatoes-tomatometer',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/zootopia-2-rotten-tomatoes-score.jpg',
#   'eventSlug': 'avatar-fire-and-ash-rotten-tomatoes-score-118',
#   'outcome': 'Yes',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766416589,
#   'conditionId': '0xc925370ecdc9d9109bff4677cf968af11546171a62091794755e8e32bdc80159',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x6b7d4852d908c9e3cb7cd0c58f4520282c70c60e20d90dadd509c0861d0804e2',
#   'price': 0.999,
#   'asset': '40064729582277602586442140675263853971918308835117843355911591891150830950346',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Will "Avatar: Fire and Ash" score at least 70 on the Rotten Tomatoes Tomatometer?',
#   'slug': 'will-avatar-fire-and-ash-score-at-least-70-on-the-rotten-tomatoes-tomatometer',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/zootopia-2-rotten-tomatoes-score.jpg',
#   'eventSlug': 'avatar-fire-and-ash-rotten-tomatoes-score-118',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766415689,
#   'conditionId': '0xe3c42c6ae8f275e8a0b6a24dd0f9c3c4924b8bfcd2f2f22273c16b555061c7ce',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0xf4a2512282937a8c2bfd3345c5f55324960b1ac9a8747bd880dcb697845c8ad1',
#   'price': 0.999,
#   'asset': '2669921056208739349138986968681462639800828591635867565297981337698059407621',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Will "Avatar: Fire and Ash" score at least 75 on the Rotten Tomatoes Tomatometer?',
#   'slug': 'will-avatar-fire-and-ash-score-at-least-75-on-the-rotten-tomatoes-tomatometer',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/avatar-fire-and-ash-rotten-tomatoes-score-118-iNxkbRMr6sGN.jpg',
#   'eventSlug': 'avatar-fire-and-ash-rotten-tomatoes-score-118',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766415407,
#   'conditionId': '0xbc1ec362c2c6e62d2ec7ad923c47b7f60308896233cbf5251d863c771dc970c4',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0xd46036a6c50b98ef2b99e8d6f69cb7efa784d1c3f9fbf334a7acf14a44f5f334',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'ILT20: Desert Vipers vs MI Emirates (Game 1) - Most Sixes MI Emirates Winner',
#   'slug': 'cruae-des-mi-2025-12-21-most-sixes-mi',
#   'icon': '',
#   'eventSlug': 'cruae-des-mi-2025-12-21-most-sixes',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766413457,
#   'conditionId': '0x662e880d22aceab341d3be1381462efd9f1f5377df91368b316eaab37b81f7d9',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x37697fdaca56247afaeb2e89a1d88fc23f814d14a808f9b1c7c19c77732f1fab',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Wildcard Academy to win 0 maps?',
#   'slug': 'cs2-wca-tri9-2025-12-22-wildcard-academy-to-win-0-maps',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/counter-strike-image-16c415c538.png',
#   'eventSlug': 'cs2-wca-tri9-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766412705,
#   'conditionId': '0x9fab3ecf6418d54e1722ed5bd502207bed09b631f470e03a736e8a3832f400a6',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0xb3062dec82daaa106e1a77e99efedd282db498a6d3abc777b36a6463d28cda1e',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Sangal to win 2 maps?',
#   'slug': 'cs2-sng2-nem-2025-12-22-sangal-to-win-2-maps',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/counter-strike-image-16c415c538.png',
#   'eventSlug': 'cs2-sng2-nem-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766412577,
#   'conditionId': '0xd445d42d47bf2a28ae00a561f7939026cb7b0925cd59cc39412f39cbdac9721a',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x2e7ebb75bb3a321b5c93dde77e4cc17865fbc30d6a170e4d5656e5e3e716883c',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': ' CSDIILIT to win 0 maps?',
#   'slug': 'cs2-csdiil-efa-2025-12-22-csdiilit-to-win-0-maps',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/counter-strike-image-16c415c538.png',
#   'eventSlug': 'cs2-csdiil-efa-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766411247,
#   'conditionId': '0xf8d398d5897fe9a745eff1eec64e8c60b5ae9aa5f4cffc233f495006c97fffa0',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0xaf6aee89a4792092bd344d87f4a57058a4537570977f5b9820ef699e3ff26930',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'Big Bash League: Sydney Thunder vs Brisbane Heat (Game 1)',
#   'slug': 'craus-syd2-bri-2025-12-22',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/cricket-ball-a0b0bf2dc9.png',
#   'eventSlug': 'craus-syd2-bri-2025-12-22',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766409361,
#   'conditionId': '0xbc1ec362c2c6e62d2ec7ad923c47b7f60308896233cbf5251d863c771dc970c4',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x344c8c21de8854be96a8045094cde371ca638363206bfe8edac782b06f7d0284',
#   'price': 0.999,
#   'asset': '41533159398653942369643110848236529814618898450353447785931595321296574979615',
#   'side': 'BUY',
#   'outcomeIndex': 0,
#   'title': 'ILT20: Desert Vipers vs MI Emirates (Game 1) - Most Sixes MI Emirates Winner',
#   'slug': 'cruae-des-mi-2025-12-21-most-sixes-mi',
#   'icon': '',
#   'eventSlug': 'cruae-des-mi-2025-12-21-most-sixes',
#   'outcome': 'Yes',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766408803,
#   'conditionId': '0xaf27504221b7e3b946142f8666edb2f442736d2e5e0c7ac757b0a106f2c8b55f',
#   'type': 'TRADE',
#   'size': 5.39,
#   'usdcSize': 5.38461,
#   'transactionHash': '0xd7cae233149d43f73d3f1e47f5fbeeb2c4bdb4dafb1cb50cbc107433571d8c54',
#   'price': 0.999,
#   'asset': '53507637497727166232324398851123230096724650741227053370247323197873038348927',
#   'side': 'SELL',
#   'outcomeIndex': 1,
#   'title': 'Will the price of Ethereum be above $3,100 on December 17?',
#   'slug': 'ethereum-above-3100-on-december-17',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/ETH+fullsize.jpg',
#   'eventSlug': 'ethereum-above-on-december-17',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766408703,
#   'conditionId': '0x65977d4806b6b725c7588ddc940c1e7c18fd311f0fd1027c29db158ae16ea03b',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0xedbcd1d896838cb1660782c2b0e8f0ebd25dda7e00ecc9be64870791c5c418bb',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'ILT20: Dubai Capitals vs Gulf Giants (Game 1) - Most Sixes Tie',
#   'slug': 'cruae-dub-gul-2025-12-21-most-sixes-tie',
#   'icon': '',
#   'eventSlug': 'cruae-dub-gul-2025-12-21-most-sixes',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766408703,
#   'conditionId': '0x9a2ed2f342ef736f3b6c9adbce62d065aa4501471fea925129e568214c2ab01f',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0xedbcd1d896838cb1660782c2b0e8f0ebd25dda7e00ecc9be64870791c5c418bb',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'ILT20: Dubai Capitals vs Gulf Giants (Game 1) - Most Sixes Dubai Capitals Winner',
#   'slug': 'cruae-dub-gul-2025-12-21-most-sixes-dub',
#   'icon': '',
#   'eventSlug': 'cruae-dub-gul-2025-12-21-most-sixes',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766408577,
#   'conditionId': '0x41d375e30af5791280716aa9edc3d3f9c01784b27d9b234232a5671e5c66a9da',
#   'type': 'REDEEM',
#   'size': 100,
#   'usdcSize': 100,
#   'transactionHash': '0x8fcc8a9c7f4a2d50a0c90255949454463729d4e67557747c192bfc763274f85c',
#   'price': 0,
#   'asset': '',
#   'side': '',
#   'outcomeIndex': 999,
#   'title': 'ILT20: Dubai Capitals vs Gulf Giants (Game 1) - Team Top Batter Tie',
#   'slug': 'cruae-dub-gul-2025-12-21-team-top-batter-tie',
#   'icon': '',
#   'eventSlug': 'cruae-dub-gul-2025-12-21-team-top-batter',
#   'outcome': '',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766406653,
#   'conditionId': '0x662e880d22aceab341d3be1381462efd9f1f5377df91368b316eaab37b81f7d9',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x7a669a0fe8478e35b9d0941767425d0cea2f11e0a360f35f4498c87e0cf1c639',
#   'price': 0.999,
#   'asset': '114442960301484957336521501088056591766149615720665464441901198367313004595908',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Wildcard Academy to win 0 maps?',
#   'slug': 'cs2-wca-tri9-2025-12-22-wildcard-academy-to-win-0-maps',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/counter-strike-image-16c415c538.png',
#   'eventSlug': 'cs2-wca-tri9-2025-12-22',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766406651,
#   'conditionId': '0x9fab3ecf6418d54e1722ed5bd502207bed09b631f470e03a736e8a3832f400a6',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0xd2498ad895d6683ac7ebad88e886ecf7621004bb91d7c46fee3ea9f6c6676797',
#   'price': 0.999,
#   'asset': '75430941991146740722101718269418967252215396946667148013522701191472309794120',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': 'Sangal to win 2 maps?',
#   'slug': 'cs2-sng2-nem-2025-12-22-sangal-to-win-2-maps',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/counter-strike-image-16c415c538.png',
#   'eventSlug': 'cs2-sng2-nem-2025-12-22',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''},
#  {'proxyWallet': '0x45deaad70997b2998fbb9433b1819178e34b409c',
#   'timestamp': 1766406455,
#   'conditionId': '0xd445d42d47bf2a28ae00a561f7939026cb7b0925cd59cc39412f39cbdac9721a',
#   'type': 'TRADE',
#   'size': 100,
#   'usdcSize': 99.9,
#   'transactionHash': '0x74a10ff8c95e509fe0b7ad91c2a1866d896d35dc95593134ed8ba625a25e539e',
#   'price': 0.999,
#   'asset': '106144925708477931657093354750988815598884220823123029875059879149030930780080',
#   'side': 'BUY',
#   'outcomeIndex': 1,
#   'title': ' CSDIILIT to win 0 maps?',
#   'slug': 'cs2-csdiil-efa-2025-12-22-csdiilit-to-win-0-maps',
#   'icon': 'https://polymarket-upload.s3.us-east-2.amazonaws.com/counter-strike-image-16c415c538.png',
#   'eventSlug': 'cs2-csdiil-efa-2025-12-22',
#   'outcome': 'No',
#   'name': 'duchanghui',
#   'pseudonym': 'Outstanding-Clogs',
#   'bio': '',
#   'profileImage': '',
#   'profileImageOptimized': ''}]

# %%
# ==================== 示例 1: 健康检查 ====================
print("示例 1: 健康检查")
print("-" * 50)
try:
    health = api.health_check()
    print(json.dumps(health, indent=2, ensure_ascii=False))
except Exception as e:
    print(f"错误: {e}")
# Out:
# 示例 1: 健康检查
# --------------------------------------------------
# 请求失败: 404 Client Error: Not Found for url: https://data-api.polymarket.com/health
# 响应内容: 404 page not found
#
# 错误: 404 Client Error: Not Found for url: https://data-api.polymarket.com/health

# %%
# ==================== 示例 2: 获取用户当前持仓 ====================
# 注意: 需要替换为实际的用户地址
print("示例 2: 获取用户当前持仓")
print("-" * 50)

# 示例用户地址 (请替换为实际地址)
example_user = "0x45deaaD70997b2998FBb9433B1819178e34B409C"

try:
    positions = api.get_positions(
        user=example_user,
        limit=10,  # 只获取前10条
        sort_by="CURRENT",  # 按当前价值排序
        sort_direction="DESC"
    )
    print(f"找到 {len(positions)} 个持仓")
    if positions:
        print("\n前3个持仓:")
        for i, pos in enumerate(positions[:3], 1):
            print(f"\n{i}. {pos.get('title', 'N/A')}")
            print(f"   当前价值: ${pos.get('currentValue', 0):.2f}")
            print(f"   盈亏: ${pos.get('cashPnl', 0):.2f} ({pos.get('percentPnl', 0):.2f}%)")
            print(f"   持仓数量: {pos.get('size', 0)}")
except Exception as e:
    print(f"错误: {e}")
    print("提示: 请确保用户地址有效，或该用户有持仓记录")
# Out:
# 示例 2: 获取用户当前持仓
# --------------------------------------------------
# 找到 9 个持仓
#
# 前3个持仓:
#
# 1. Will Drake release a new song in 2025?
#    当前价值: $99.95
#    盈亏: $0.06 (0.06%)
#    持仓数量: 100
#
# 2. Jarrett Allen: Points Over 14.5
#    当前价值: $99.85
#    盈亏: $-0.05 (-0.05%)
#    持仓数量: 100
#
# 3. Donovan Mitchell: Points Over 30.5
#    当前价值: $99.85
#    盈亏: $-0.05 (-0.05%)
#    持仓数量: 100

# %%
# ==================== 示例 3: 获取交易记录 ====================
print("示例 3: 获取交易记录")
print("-" * 50)

try:
    # 获取特定用户的交易记录
    trades = api.get_trades(
        user=example_user,
        limit=10,
        sort_by="TIMESTAMP",
        sort_direction="DESC"
    )
    print(f"找到 {len(trades)} 笔交易")
    if trades:
        print("\n最近3笔交易:")
        for i, trade in enumerate(trades[:3], 1):
            print(f"\n{i}. 交易ID: {trade.get('id', 'N/A')}")
            print(f"   时间: {trade.get('timestamp', 'N/A')}")
            print(f"   金额: ${trade.get('amount', 0):.2f}")
except Exception as e:
    print(f"错误: {e}")
# Out:
# 示例 3: 获取交易记录
# --------------------------------------------------
# 找到 10 笔交易
#
# 最近3笔交易:
#
# 1. 交易ID: N/A
#    时间: 1766470943
#    金额: $0.00
#
# 2. 交易ID: N/A
#    时间: 1766469275
#    金额: $0.00
#
# 3. 交易ID: N/A
#    时间: 1766469263
#    金额: $0.00

# %%
# ==================== 示例 4: 获取用户活动 ====================
print("示例 4: 获取用户活动")
print("-" * 50)

try:
    activities = api.get_user_activity(
        user=example_user,
        limit=10000
    )
    print(f"找到 {len(activities)} 条活动记录")
    if activities:
        print("\n最近3条活动:")
        for i, activity in enumerate(activities[:3], 1):
            print(f"\n{i}. {json.dumps(activity, indent=2, ensure_ascii=False)}")
except Exception as e:
    print(f"错误: {e}")
# Out:
# 示例 4: 获取用户活动
# --------------------------------------------------
# 请求失败: HTTPSConnectionPool(host='data-api.polymarket.com', port=443): Max retries exceeded with url: /activity?user=0x45deaaD70997b2998FBb9433B1819178e34B409C&limit=10000&offset=0&sortBy=TIMESTAMP&sortDirection=DESC (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# 错误: HTTPSConnectionPool(host='data-api.polymarket.com', port=443): Max retries exceeded with url: /activity?user=0x45deaaD70997b2998FBb9433B1819178e34B409C&limit=10000&offset=0&sortBy=TIMESTAMP&sortDirection=DESC (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))

# %%
# ==================== 示例 4.5: 循环获取所有用户活动记录 ====================
print("示例 4.5: 循环获取所有用户活动记录")
print("-" * 50)

try:
    # 使用 get_all_user_activity 获取所有历史记录
    all_activities = api.get_all_user_activity(
        user=example_user,
        batch_size=100,  # 每批获取100条
        verbose=True  # 显示进度信息
    )
    
    print(f"\n总共获取了 {len(all_activities)} 条活动记录")
    
    if all_activities:
        print("\n最早和最晚的活动记录:")
        print(f"最早: {all_activities[-1].get('timestamp', 'N/A')}")
        print(f"最晚: {all_activities[0].get('timestamp', 'N/A')}")
        
        # 按类型统计
        activity_types = {}
        for activity in all_activities:
            activity_type = activity.get('type', 'UNKNOWN')
            activity_types[activity_type] = activity_types.get(activity_type, 0) + 1
        
        print("\n活动类型统计:")
        for activity_type, count in sorted(activity_types.items(), key=lambda x: x[1], reverse=True):
            print(f"  {activity_type}: {count} 条")
        
        # 显示前3条记录
        print("\n前3条活动记录:")
        for i, activity in enumerate(all_activities[:3], 1):
            print(f"\n{i}. 类型: {activity.get('type', 'N/A')}")
            print(f"   时间戳: {activity.get('timestamp', 'N/A')}")
            print(f"   详情: {json.dumps(activity, indent=2, ensure_ascii=False)}")
    
except Exception as e:
    print(f"错误: {e}")
    import traceback
    traceback.print_exc()
# Out:
# 示例 4.5: 循环获取所有用户活动记录
# --------------------------------------------------
# 开始获取用户 0x45deaaD70997b2998FBb9433B1819178e34B409C 的所有活动记录...
# 正在获取第 1 批 (offset: 0, limit: 100)...
#   已获取 100 条记录，累计: 100 条
# 正在获取第 2 批 (offset: 100, limit: 100)...
#   已获取 100 条记录，累计: 200 条
# 正在获取第 3 批 (offset: 200, limit: 100)...
#   已获取 100 条记录，累计: 300 条
# 正在获取第 4 批 (offset: 300, limit: 100)...
#   已获取 100 条记录，累计: 400 条
# 正在获取第 5 批 (offset: 400, limit: 100)...
#   已获取 100 条记录，累计: 500 条
# 正在获取第 6 批 (offset: 500, limit: 100)...
#   已获取 100 条记录，累计: 600 条
# 正在获取第 7 批 (offset: 600, limit: 100)...
#   已获取 100 条记录，累计: 700 条
# 正在获取第 8 批 (offset: 700, limit: 100)...
#   已获取 100 条记录，累计: 800 条
# 正在获取第 9 批 (offset: 800, limit: 100)...
#   已获取 100 条记录，累计: 900 条
# 正在获取第 10 批 (offset: 900, limit: 100)...
#   已获取 100 条记录，累计: 1000 条
# 正在获取第 11 批 (offset: 1000, limit: 100)...
#   已获取 100 条记录，累计: 1100 条
# 正在获取第 12 批 (offset: 1100, limit: 100)...
#   已获取 100 条记录，累计: 1200 条
# 正在获取第 13 批 (offset: 1200, limit: 100)...
#   已获取 100 条记录，累计: 1300 条
# 正在获取第 14 批 (offset: 1300, limit: 100)...
#   已获取 100 条记录，累计: 1400 条
# 正在获取第 15 批 (offset: 1400, limit: 100)...
#   已获取 100 条记录，累计: 1500 条
# 正在获取第 16 批 (offset: 1500, limit: 100)...
#   已获取 100 条记录，累计: 1600 条
# 正在获取第 17 批 (offset: 1600, limit: 100)...
#   已获取 100 条记录，累计: 1700 条
# 正在获取第 18 批 (offset: 1700, limit: 100)...
#   已获取 100 条记录，累计: 1800 条
# 正在获取第 19 批 (offset: 1800, limit: 100)...
#   已获取 100 条记录，累计: 1900 条
# 正在获取第 20 批 (offset: 1900, limit: 100)...
#   已获取 100 条记录，累计: 2000 条
# 正在获取第 21 批 (offset: 2000, limit: 100)...
#   已获取 100 条记录，累计: 2100 条
# 正在获取第 22 批 (offset: 2100, limit: 100)...
#   已获取 100 条记录，累计: 2200 条
# 正在获取第 23 批 (offset: 2200, limit: 100)...
#   已获取 100 条记录，累计: 2300 条
# 正在获取第 24 批 (offset: 2300, limit: 100)...
#   已获取 100 条记录，累计: 2400 条
# 正在获取第 25 批 (offset: 2400, limit: 100)...
#   已获取 100 条记录，累计: 2500 条
# 正在获取第 26 批 (offset: 2500, limit: 100)...
#   已获取 100 条记录，累计: 2600 条
# 正在获取第 27 批 (offset: 2600, limit: 100)...
#   已获取 100 条记录，累计: 2700 条
# 正在获取第 28 批 (offset: 2700, limit: 100)...
#   已获取 100 条记录，累计: 2800 条
# 正在获取第 29 批 (offset: 2800, limit: 100)...
#   已获取 100 条记录，累计: 2900 条
# 正在获取第 30 批 (offset: 2900, limit: 100)...
#   已获取 100 条记录，累计: 3000 条
# 正在获取第 31 批 (offset: 3000, limit: 100)...
#   已获取 100 条记录，累计: 3100 条
# 正在获取第 32 批 (offset: 3100, limit: 100)...
#   已获取 100 条记录，累计: 3200 条
# 正在获取第 33 批 (offset: 3200, limit: 100)...
#   已获取 100 条记录，累计: 3300 条
# 正在获取第 34 批 (offset: 3300, limit: 100)...
#   已获取 100 条记录，累计: 3400 条
# 正在获取第 35 批 (offset: 3400, limit: 100)...
#   已获取 100 条记录，累计: 3500 条
# 正在获取第 36 批 (offset: 3500, limit: 100)...
#   已获取 100 条记录，累计: 3600 条
# 正在获取第 37 批 (offset: 3600, limit: 100)...
#   已获取 100 条记录，累计: 3700 条
# 正在获取第 38 批 (offset: 3700, limit: 100)...
#   已获取 100 条记录，累计: 3800 条
# 正在获取第 39 批 (offset: 3800, limit: 100)...
#   已获取 100 条记录，累计: 3900 条
# 正在获取第 40 批 (offset: 3900, limit: 100)...
#   已获取 100 条记录，累计: 4000 条
# 正在获取第 41 批 (offset: 4000, limit: 100)...
#   已获取 100 条记录，累计: 4100 条
# 正在获取第 42 批 (offset: 4100, limit: 100)...
#   已获取 100 条记录，累计: 4200 条
# 正在获取第 43 批 (offset: 4200, limit: 100)...
#   已获取 100 条记录，累计: 4300 条
# 正在获取第 44 批 (offset: 4300, limit: 100)...
#   已获取 100 条记录，累计: 4400 条
# 正在获取第 45 批 (offset: 4400, limit: 100)...
#   已获取 100 条记录，累计: 4500 条
# 正在获取第 46 批 (offset: 4500, limit: 100)...
#   已获取 100 条记录，累计: 4600 条
# 正在获取第 47 批 (offset: 4600, limit: 100)...
#   已获取 100 条记录，累计: 4700 条
# 正在获取第 48 批 (offset: 4700, limit: 100)...
#   已获取 100 条记录，累计: 4800 条
# 正在获取第 49 批 (offset: 4800, limit: 100)...
#   已获取 100 条记录，累计: 4900 条
# 正在获取第 50 批 (offset: 4900, limit: 100)...
#   已获取 100 条记录，累计: 5000 条
# 正在获取第 51 批 (offset: 5000, limit: 100)...
#   已获取 100 条记录，累计: 5100 条
# 正在获取第 52 批 (offset: 5100, limit: 100)...
#   已获取 100 条记录，累计: 5200 条
# 正在获取第 53 批 (offset: 5200, limit: 100)...
#   已获取 100 条记录，累计: 5300 条
# 正在获取第 54 批 (offset: 5300, limit: 100)...
#   已获取 100 条记录，累计: 5400 条
# 正在获取第 55 批 (offset: 5400, limit: 100)...
#   已获取 100 条记录，累计: 5500 条
# 正在获取第 56 批 (offset: 5500, limit: 100)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 7
#       3 print("-" * 50)
#       5 try:
#       6     # 使用 get_all_user_activity 获取所有历史记录
# ----> 7     all_activities = api.get_all_user_activity(
#       8         user=example_user,
#       9         batch_size=100,  # 每批获取100条
#      10         verbose=True  # 显示进度信息
#      11     )
#      13     print(f"\n总共获取了 {len(all_activities)} 条活动记录")
#      15     if all_activities:
#
# Cell In[14], line 204, in PolymarketDataAPI.get_all_user_activity(self, user, sort_by, sort_direction, batch_size, max_records, verbose)
#     201     print(f"正在获取第 {offset // batch_size + 1} 批 (offset: {offset}, limit: {batch_size})...")
#     203 # 获取当前批次
# --> 204 batch = self.get_user_activity(
#     205     user=user,
#     206     limit=batch_size,
#     207     offset=offset,
#     208     sort_by=sort_by,
#     209     sort_direction=sort_direction
#     210 )
#     212 # 如果没有数据，说明已经获取完所有记录
#     213 if not batch or len(batch) == 0:
#
# Cell In[14], line 166, in PolymarketDataAPI.get_user_activity(self, user, limit, offset, sort_by, sort_direction)
#     147 """
#     148 获取用户活动
#     149 GET /activity
#    (...)
#     156     sort_direction: 排序方向 (ASC, DESC)
#     157 """
#     158 params = {
#     159     "user": user,
#     160     "limit": limit,
#    (...)
#     163     "sortDirection": sort_direction
#     164 }
# --> 166 return self._get("/activity", params=params)
#
# Cell In[14], line 29, in PolymarketDataAPI._get(self, endpoint, params)
#      27 url = f"{self.base_url}{endpoint}"
#      28 try:
# ---> 29     response = self.session.get(url, params=params, timeout=30)
#      30     response.raise_for_status()
#      31     return response.json()
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/lib/python3.12/http/client.py:1423, in HTTPConnection.getresponse(self)
#    1421 try:
#    1422     try:
# -> 1423         response.begin()
#    1424     except ConnectionError:
#    1425         self.close()
#
# File /opt/anaconda3/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/anaconda3/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/anaconda3/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# ==================== 示例 5: 获取持仓总价值 ====================
print("示例 5: 获取持仓总价值")
print("-" * 50)

try:
    total_value = api.get_total_value(user=example_user)
    print("持仓总价值:")
    print(json.dumps(total_value, indent=2, ensure_ascii=False))
except Exception as e:
    print(f"错误: {e}")
# Out:
# 示例 5: 获取持仓总价值
# --------------------------------------------------
# 请求失败: 404 Client Error: Not Found for url: https://data-api.polymarket.com/total-value?user=0x45deaaD70997b2998FBb9433B1819178e34B409C
# 响应内容: 404 page not found
#
# 错误: 404 Client Error: Not Found for url: https://data-api.polymarket.com/total-value?user=0x45deaaD70997b2998FBb9433B1819178e34B409C

# %%
# ==================== 示例 6: 获取已关闭的持仓 ====================
print("示例 6: 获取已关闭的持仓")
print("-" * 50)

try:
    closed_positions = api.get_closed_positions(
        user=example_user,
        limit=10
    )
    print(f"找到 {len(closed_positions)} 个已关闭的持仓")
    if closed_positions:
        print("\n前3个已关闭持仓:")
        for i, pos in enumerate(closed_positions[:3], 1):
            print(f"\n{i}. {pos.get('title', 'N/A')}")
            print(f"   已实现盈亏: ${pos.get('realizedPnl', 0):.2f}")
except Exception as e:
    print(f"错误: {e}")
# Out:
# 示例 6: 获取已关闭的持仓
# --------------------------------------------------
# 找到 10 个已关闭的持仓
#
# 前3个已关闭持仓:
#
# 1. Will Drake release a new song in 2025?
#    已实现盈亏: $0.11
#
# 2. 49ers Team Total: O/U 35.5
#    已实现盈亏: $0.10
#
# 3. Grizzlies vs. Thunder: 1H O/U 118.5
#    已实现盈亏: $0.10

# %%
# ==================== 示例 7: 获取交易员排行榜 ====================
print("示例 7: 获取交易员排行榜")
print("-" * 50)

try:
    leaderboard = api.get_trader_leaderboard(
        period="ALL_TIME",  # 可选: ALL_TIME, WEEK, MONTH, YEAR
        limit=10
    )
    print(f"排行榜前 {len(leaderboard)} 名:")
    for i, trader in enumerate(leaderboard[:5], 1):
        print(f"\n{i}. 用户: {trader.get('user', 'N/A')}")
        print(f"   排名: {trader.get('rank', 'N/A')}")
        print(f"   数据: {json.dumps(trader, indent=2, ensure_ascii=False)}")
except Exception as e:
    print(f"错误: {e}")

# %%
# ==================== 示例 8: 获取市场顶级持有者 ====================
print("示例 8: 获取市场顶级持有者")
print("-" * 50)

# 注意: 需要提供 market (条件ID) 或 event_id
# 这里使用 event_id 作为示例
try:
    # 示例: 使用 event_id (请替换为实际的事件ID)
    top_holders = api.get_top_holders(
        event_id=12345,  # 请替换为实际的事件ID
        limit=10
    )
    print(f"找到 {len(top_holders)} 个顶级持有者")
    if top_holders:
        print("\n前3个持有者:")
        for i, holder in enumerate(top_holders[:3], 1):
            print(f"\n{i}. {json.dumps(holder, indent=2, ensure_ascii=False)}")
except Exception as e:
    print(f"错误: {e}")
    print("提示: 请提供有效的 market 或 event_id 参数")

# %% [markdown]
# ## 完整 API 方法列表
#
# ### Health
# - `health_check()` - 健康检查端点
#
# ### Core Endpoints
# - `get_positions(user, ...)` - 获取用户当前持仓
#   - 必需参数: `user` (用户地址)
#   - 可选参数: `market`, `event_id`, `size_threshold`, `redeemable`, `mergeable`, `limit`, `offset`, `sort_by`, `sort_direction`, `title`
#
# - `get_trades(user=None, market=None, ...)` - 获取用户或市场的交易记录
#   - 可选参数: `user`, `market`, `event_id`, `limit`, `offset`, `sort_by`, `sort_direction`
#
# - `get_user_activity(user, ...)` - 获取用户活动
#   - 必需参数: `user` (用户地址)
#   - 可选参数: `limit`, `offset`, `sort_by`, `sort_direction`
#
# - `get_top_holders(market=None, event_id=None, ...)` - 获取市场顶级持有者
#   - 可选参数: `market` 或 `event_id` (至少一个), `limit`, `offset`
#
# - `get_total_value(user, ...)` - 获取用户持仓总价值
#   - 必需参数: `user` (用户地址)
#   - 可选参数: `market`, `event_id`
#
# - `get_closed_positions(user, ...)` - 获取用户已关闭的持仓
#   - 必需参数: `user` (用户地址)
#   - 可选参数: `market`, `event_id`, `limit`, `offset`, `sort_by`, `sort_direction`
#
# - `get_trader_leaderboard(period='ALL_TIME', ...)` - 获取交易员排行榜
#   - 可选参数: `period` (ALL_TIME, WEEK, MONTH, YEAR), `limit`, `offset`
#
# ## 注意事项
#
# 1. **用户地址格式**: 必须是 0x 开头的 42 位十六进制字符串
# 2. **参数互斥**: `market` 和 `event_id` 在某些端点中互斥，不能同时使用
# 3. **分页**: 使用 `limit` 和 `offset` 参数进行分页查询
# 4. **错误处理**: 所有方法都会抛出异常，建议使用 try-except 进行错误处理
# 5. **API 限制**: 注意 API 的速率限制，避免频繁请求
#
# ## 参考文档
#
# - [Polymarket Data-API 文档](https://docs.polymarket.com/api-reference/data-api)
# - [获取当前持仓端点](https://docs.polymarket.com/api-reference/core/get-current-positions-for-a-user)
